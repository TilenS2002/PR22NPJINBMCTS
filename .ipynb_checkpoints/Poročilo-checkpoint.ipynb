# %% [markdown]
# # POROČILO: Statistika okoliščin prometnih nesreč v Sloveniji v letu 2021 in 2022

# %% [markdown]
# ### Projektna naloga pri podatkovnemu rudarjenju 2023
#
# Avtorji:
# Nina Plevnik, Jernej Ivančič, Nejc Brnelič, Tilen Smrdel, Miha Ciglar

# %% [markdown]
# ### Problem: Prometne nesreče so velik povzročitelj fizičnih poškodb in smrti v Sloveniji.
#
# Podatki: Za bazo podatkov smo uporabili analizo prometne varnosti za leto 2022. V bazi so združeni vsi podatki o prometnih nesrečah in udeleženih osebah, ki so nastopale kot povzročitelj ali poškodovanec/žrtev. Baza zajema vse prometne nesreče, ki si jih je ogledala in analizirala policija. V bazi podatkov smo zasledili tudi nekaj napak pri vnosu, in sicer pri formatiranju določenih podatkov. Celotno ločevanje podatkov in popravljanje formatiranja podatkov smo opravili pred analizami in vizualizacijami.

# %% [markdown]
# ### **1. vprašanje: Kako oseba vpliva na nesrečo?**

# %% [markdown]
# **Ali izkušnje na cesti oz. obdobje imetja izpita vpliva na število povzročenih nesreč?**
#
# Ugotovitev: Po naših rezultatih smo opazili, da med mladostniki in starostniki ni opaženega večjega vpliva obdobja imetja izpita na udeležencih v prometnih nesrečah:
#
# - Procent nesreč, ki jih je povzročil mladi voznik: 9.38%,
# - Procent nesreč, ki jih je povzročil stari voznik: 10.45%.

# %% [markdown]
# **Ali je bolj izkušen voznik večkrat v nesreči zaradi neprilagojene hitrosti?**
#
# Ugotovitev: Za boljšo primerjavo smo prav tako izračunali tudi kokoeficient korelacije. Dobili smo rezultat -0.64, kar kaže na močno negativno korelacijo, ta rezultat podpre našo hipotezo, da izkušne vplivajo na vpadanje količine povzročenih prometnih nesreč.
# Nato smo za za boljšo oceno statistične značilnosti rezultatov izračunali še vrednost P, ta je bila 3,10 e-68. P vrednost najpogosteje napove ali je razultat posledica naklučja, kar pa v našem primeru težko potrdimo ne glede na dobljen rezultat, saj bi bilo potrebno naše rezultate predhodno normalizirati.
#
# Graf:
# ![Figure_1-3.png](attachment:Figure_1-3.png)

# %% [markdown]
# **Katera skupina večkrat ne upošteva cestnih pravil?**
#
# Ugotovitev: Po grafu je razvidno da je velik delež nesreč zaradi neupoštevanja cestih pravil povzročen v starostni skupini 20+ let, kar nam pove da se z časom ljudem veča možnost nesreče zaradi neupoštevanja pravil. Vrednosti sta podobni prejšnji ugotovitvi.
#
# Graf:
# ![Figure_2.png](attachment:Figure_2.png)

# %% [markdown]
# **Ali mladi udeleženci res povzročijo številčnejše število nesreč kot ostali udeleženci? So to morda starejši?**
#
# **Ugotovitev:** Graf nakazuje da so mladi udeleženci v starostni skupini med 18 in 25 let povzročili največ nesreč, takoj za njimi pa starostna skupina 40 do 49 letniki.
#
# Graf:
# ![Figure_5.png](attachment:Figure_5.png)

# %% [markdown]
# **Ali spol in starost res vplivata na kakovost voznika?**
#
# **Ugotovitve:** pač ja
#
# Graf:
# ![prenos.png](attachment:prenos.png)

# %% [markdown]
# ### **2. vprašanje: Ali vreme in cestišče vpliva na nesrečo?**

# %% [markdown]
# **Ali čas dneva in dan v tednu vplivata na število nesreč?**
#
# **Ugotovitev:** Iz toplotnega zemljevida je razvidno da imata dan in čas velik vpliv na število nesreč, in sicer po rezultatih naj bi bil najbolj kritičen dan petek popoldne. Zakaj pride do več nesreč v tem času je lahko več razlogov, npr. ljudje prihajajo domov iz službe itd. Nesreče so povezane z prometnimi konicami.
#
# Graf:
# ![Figure_3.png](attachment:Figure_3.png)

# %% [markdown]
# **Ali nekateri dnevi npr. petek, sobota izstopajo z alkoholom?**
#
# **Ugotovitve:** Po rezultatih je razvidno da z alkoholom najbolj izstopa sobota, takoj za tem pa petek. Te ugotovitve lahko povežemo s prejšnjimi rezultati o številu nesreč po dnevu in času.
#
# Graf:
# ![output.png](attachment:output.png)

# %% [markdown]
# **V katerem letnem času je največ nesreč? ali na le te vpliva vreme?**
#
# **Ugotovitve:** Razvidno je, da je največ prometnih nesreč začetek jeseni, v mesecu Septembru. Večji razlog za to je najverjetneje mastna cesta zaradi odpadajočega listja.
#
# Graf:
# ![Figure_4.png](attachment:Figure_4.png)

# %% [markdown]
# **Katere nesreče so najbolj pogoste v vremenih kot sta sneg in megla? Kakšni vzroki nesreč so najbolj pogosti?**
#
# **Ugotovitve:**
#
# Graf:
# ![wAz6RQ4ndRiogAAAABJRU5ErkJggg.png](attachment:wAz6RQ4ndRiogAAAABJRU5ErkJggg.png)

# %% [markdown]
# **Kateri tipi ceste so najbolj nevarni? (suha proti mokra)**
#
# **Ugotovitve:** Karambolov v stacionarne objekte (npr. parkiran avto, stavba, itd.) je bilo na mokri (ali poledeneli, poškodovani) cesti 4.9936% več kot karambolov v stacionarne objekte na suhi (nepoškodovani) cesti.
#
# - STOJI: 7158
# - SUHA: 22534
# - MOKRA: 6749
#
# - STOJI & SUHA: 5444
# - STOJI & MOKRA: 1714

# %% [markdown]
# ### **3. vprašanje? Vozilo in poškodba**

# %% [markdown]
# **Ali je poškodba odvisna od vozila povzročitelja?**
# mejbi

# %% [markdown]
# **Kako se razlikujejo poškodbe udeležencev glede na tip udeležbe(pešec, kolesar, motor itd.)?**
#
# **Ugotovitve:** Vozniki motornih vozil so utrpeli več lažjh in hudih poškodb v primerjavi z ostalimi udeleženci v prometu.
#
# Graf:
# ![Y5KFAI~1.PNG](attachment:Y5KFAI~1.PNG)

# %% [markdown]
# **Kateri so najpogostejši udeleženci nesreče?**
#
# **Ugotovitve:** Naj pogostejši udeleženci prometnih nesreč so vozniki osebnih avtomobilov.
#
# Graf:
# ![Figure_6.png](attachment:Figure_6.png)

# %% [markdown]
# **Ali lahko napovemo posledico telesne poškodbe glede na druge faktorje nesreče?**
#
# **Ugotovitve:** Za to vprašanje smo naredili:...blabla jernej povej kk si dubu une selected_features = ['UraPN', 'Starost', 'VrstaUdelezenca', 'PoskodbaUdelezenca',
#        'MeseciIzpita', 'VzrokNesrece', 'TipNesrece', 'VrstaCesteNaselja',
#        'VremenskeOkoliscine', 'StanjePrometa']
#
# Nato smo rezultate tega uporabili za učenje modela, ki je glede na le te atribute predvideli kakšna bo klasifikacija nesreče.
# Uporabili smo model RandomForestClassifier, ki kaže rezultate z 0.872 natančnostjo. Poročilo o razvrstitvi zagotavlja podrobno analizo delovanja modela za vsak razred. Vključuje meritve natančnosti, priklica, rezultat F1 in podpore. Na splošno je model zagotovljiv, s povprečno oceno F1 - 0,86.

# %% [markdown]
# **Ali uporaba varnostnega pasu vpliva na izid poškodbe?**
#
# **Ugotovitve:** yes
#
# Graf:
# ![pasPo%C5%A1kodba.png](attachment:pasPo%C5%A1kodba.png)

# %% [markdown]
# ## Glavne ugotovitve in rezultati:

# %% [markdown]
# ### **Ugotovitve:**

# %% [markdown]
# Po večjem delu in obdelavi podatkov smo preko več poizvedb zasledili korelacije med podatki, katere bi pričakovali iz realnih okoliščin. Vse od izkušenj, starosti in do vremenskih ter cestnih razmer nam je podalo rezultate skladne z resničnimi vzroki prometnih nesreč.

# %% [markdown]
# ### Rezultati:

# %% [markdown]
# Z obdelavo numeričnih rezultatov smo dobili grafično predstavitev katera lepo prikazuje stanje prometnih razmer v Sloveniji. Prikazali smo jih z scatter ploti, toplotnimi zemljevidi iz katerih dobimo lažje berljive podatke/informacije.
